# %%
import matplotlib.pyplot as plt

# Provided data
suspense_ratings_human = [5.565217391, 5, 4.826086957, 5.739130435, 5.52173913, 6.826086957, 7.304347826,
                          5.434782609, 6.391304348, 7.47826087, 7.043478261, 5.869565217, 6.739130435,
                          6.956521739, 6.47826087, 5.956521739, 4.652173913, 4.260869565, 5.173913043,
                          4.086956522, 4.173913043, 4.304347826, 5, 4.043478261, 4.217391304, 4.434782609,
                          5.347826087, 6.217391304, 5.434782609, 4.782608696, 6.173913043, 5.956521739,
                          6.47826087, 5, 4.739130435, 5.173913043, 6.304347826, 6.434782609, 5.260869565,
                          5.304347826, 5.956521739, 4.304347826, 5.260869565, 4.391304348, 4.956521739,
                          5.695652174, 5.043478261, 5.826086957, 5.043478261, 4.913043478, 5.217391304,
                          6.217391304, 6.391304348, 6.52173913, 7.217391304, 6.565217391, 5.52173913,
                          4.347826087, 3.869565217, 7, 7.565217391, 6.52173913, 6.260869565, 6.043478261,
                          4.913043478]

suspense_ratings_llama = [5, 2, 1, 9, 3, 8, 9, 10, 9, 10, 9, 8, 6, 8, 10, 5, 2, 4, 6, 5, 8, 4, 9, 5, 1, 3, 6, 8, 9, 10, 10, 10, 10, 10, 8, 5, 8, 10, 9, 10, 10, 10, 9, 8, 6, 10, 10, 10, 10, 8, 6, 10, 10, 10, 10, 10, 10, 1, 1, 10, 10, 10, 10, 10, 1]

# Generate x-axis labels
text_segments = list(range(1, len(suspense_ratings_human) + 1))

# Create the plot
plt.figure(figsize=(14, 7))

# Plot human ratings
plt.plot(text_segments, suspense_ratings_human, label='Human Ratings', color='blue', marker='o')

# Plot llama ratings
plt.plot(text_segments, suspense_ratings_llama, label='Llama Ratings', color='orange', marker='x')

# Labeling the plot
plt.title('Average Suspense Rating Comparison (Human vs Llama)')
plt.xlabel('Text Segment')
plt.ylabel('Average Suspense Rating')
plt.grid(True)
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Provided data
suspense_ratings_human = [5.565217391, 5, 4.826086957, 5.739130435, 5.52173913, 6.826086957, 7.304347826,
                          5.434782609, 6.391304348, 7.47826087, 7.043478261, 5.869565217, 6.739130435,
                          6.956521739, 6.47826087, 5.956521739, 4.652173913, 4.260869565, 5.173913043,
                          4.086956522, 4.173913043, 4.304347826, 5, 4.043478261, 4.217391304, 4.434782609,
                          5.347826087, 6.217391304, 5.434782609, 4.782608696, 6.173913043, 5.956521739,
                          6.47826087, 5, 4.739130435, 5.173913043, 6.304347826, 6.434782609, 5.260869565,
                          5.304347826, 5.956521739, 4.304347826, 5.260869565, 4.391304348, 4.956521739,
                          5.695652174, 5.043478261, 5.826086957, 5.043478261, 4.913043478, 5.217391304,
                          6.217391304, 6.391304348, 6.52173913, 7.217391304, 6.565217391, 5.52173913,
                          4.347826087, 3.869565217, 7, 7.565217391, 6.52173913, 6.260869565, 6.043478261,
                          4.913043478]

suspense_ratings_llama = [5, 2, 1, 9, 3, 8, 9, 10, 9, 10, 9, 8, 6, 8, 10, 5, 2, 4, 6, 5, 8, 4, 9, 5, 1, 3, 6, 8, 9, 10, 10, 10, 10, 10, 8, 5, 8, 10, 9, 10, 10, 10, 9, 8, 6, 10, 10, 10, 10, 8, 6, 10, 10, 10, 10, 10, 10, 1, 1, 10, 10, 10, 10, 10, 1]

# Calculate differences (deltas)
deltas_human = [suspense_ratings_human[i] - suspense_ratings_human[i - 1] for i in range(1, len(suspense_ratings_human))]
deltas_llama = [suspense_ratings_llama[i] - suspense_ratings_llama[i - 1] for i in range(1, len(suspense_ratings_llama))]

# Generate x-axis labels for deltas as text segments
text_segments_deltas = list(range(2, len(suspense_ratings_human) + 1))

# Create the plot
plt.figure(figsize=(14, 7))

# Plot deltas for human ratings
plt.plot(text_segments_deltas, deltas_human, marker='o', linestyle='-', color='r', label='Human Ratings Delta')

# Plot deltas for llama ratings
plt.plot(text_segments_deltas, deltas_llama, marker='o', linestyle='-', color='b', label='Llama Ratings Delta')

# Labeling the plot
plt.title('Change in Average Suspense Rating Across Text Segments (Human vs Llama)')
plt.xlabel('Text Segment')
plt.ylabel('Change in Average Suspense Rating (Delta)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)  # Add a horizontal line at y=0
plt.xticks(text_segments_deltas, rotation=90)  # Rotate x-axis labels if necessary
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
suspense_ratings_human = [5.565217391, 5, 4.826086957, 5.739130435, 5.52173913, 6.826086957, 7.304347826,
                          5.434782609, 6.391304348, 7.47826087, 7.043478261, 5.869565217, 6.739130435,
                          6.956521739, 6.47826087, 5.956521739, 4.652173913, 4.260869565, 5.173913043,
                          4.086956522, 4.173913043, 4.304347826, 5, 4.043478261, 4.217391304, 4.434782609,
                          5.347826087, 6.217391304, 5.434782609, 4.782608696, 6.173913043, 5.956521739,
                          6.47826087, 5, 4.739130435, 5.173913043, 6.304347826, 6.434782609, 5.260869565,
                          5.304347826, 5.956521739, 4.304347826, 5.260869565, 4.391304348, 4.956521739,
                          5.695652174, 5.043478261, 5.826086957, 5.043478261, 4.913043478, 5.217391304,
                          6.217391304, 6.391304348, 6.52173913, 7.217391304, 6.565217391, 5.52173913,
                          4.347826087, 3.869565217, 7, 7.565217391, 6.52173913, 6.260869565, 6.043478261,
                          4.913043478]

suspense_ratings_llama = [5, 2, 1, 9, 3, 8, 9, 10, 9, 10, 9, 8, 6, 8, 10, 5, 2, 4, 6, 5, 8, 4, 9, 5, 1, 3, 6, 8, 9, 10, 10, 10, 10, 10, 8, 5, 8, 10, 9, 10, 10, 10, 9, 8, 6, 10, 10, 10, 10, 8, 6, 10, 10, 10, 10, 10, 10, 1, 1, 10, 10, 10, 10, 10, 1]

# Calculate differences (deltas)
deltas_human = [suspense_ratings_human[i] - suspense_ratings_human[i - 1] for i in range(1, len(suspense_ratings_human))]
deltas_llama = [suspense_ratings_llama[i] - suspense_ratings_llama[i - 1] for i in range(1, len(suspense_ratings_llama))]

# Generate x-axis labels for deltas as text segments
text_segments_deltas = list(range(2, len(suspense_ratings_human) + 1))

# Set width of bars
bar_width = 0.35

# Set positions of bars on x-axis
r1 = np.arange(len(deltas_human))
r2 = [x + bar_width for x in r1]

# Create the plot
plt.figure(figsize=(14, 7))

# Plot deltas for human ratings
plt.bar(r1, deltas_human, color='r', width=bar_width, edgecolor='grey', label='Human Ratings Delta')

# Plot deltas for llama ratings
plt.bar(r2, deltas_llama, color='b', width=bar_width, edgecolor='grey', label='Llama Ratings Delta')

# Labeling the plot
plt.title('Change in Average Suspense Rating Across Text Segments (Human vs Llama)')
plt.xlabel('Text Segment')
plt.ylabel('Change in Average Suspense Rating (Delta)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)  # Add a horizontal line at y=0
plt.xticks([r + bar_width / 2 for r in range(len(deltas_human))], text_segments_deltas, rotation=90)  # Rotate x-axis labels if necessary
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
suspense_ratings_human = [5.565217391, 5, 4.826086957, 5.739130435, 5.52173913, 6.826086957, 7.304347826,
                          5.434782609, 6.391304348, 7.47826087, 7.043478261, 5.869565217, 6.739130435,
                          6.956521739, 6.47826087, 5.956521739, 4.652173913, 4.260869565, 5.173913043,
                          4.086956522, 4.173913043, 4.304347826, 5, 4.043478261, 4.217391304, 4.434782609,
                          5.347826087, 6.217391304, 5.434782609, 4.782608696, 6.173913043, 5.956521739,
                          6.47826087, 5, 4.739130435, 5.173913043, 6.304347826, 6.434782609, 5.260869565,
                          5.304347826, 5.956521739, 4.304347826, 5.260869565, 4.391304348, 4.956521739,
                          5.695652174, 5.043478261, 5.826086957, 5.043478261, 4.913043478, 5.217391304,
                          6.217391304, 6.391304348, 6.52173913, 7.217391304, 6.565217391, 5.52173913,
                          4.347826087, 3.869565217, 7, 7.565217391, 6.52173913, 6.260869565, 6.043478261,
                          4.913043478]

suspense_ratings_llama = [5, 2, 1, 9, 3, 8, 9, 10, 9, 10, 9, 8, 6, 8, 10, 5, 2, 4, 6, 5, 8, 4, 9, 5, 1, 3, 6, 8, 9, 10, 10, 10, 10, 10, 8, 5, 8, 10, 9, 10, 10, 10, 9, 8, 6, 10, 10, 10, 10, 8, 6, 10, 10, 10, 10, 10, 10, 1, 1, 10, 10, 10, 10, 10, 1]

# Calculate differences (deltas)
deltas_human = [suspense_ratings_human[i] - suspense_ratings_human[i - 1] for i in range(1, len(suspense_ratings_human))]
deltas_llama = [suspense_ratings_llama[i] - suspense_ratings_llama[i - 1] for i in range(1, len(suspense_ratings_llama))]

# Generate x-axis labels for deltas as text segments
text_segments_deltas = list(range(2, len(suspense_ratings_human) + 1))

# Calculate agreement values
agreement = []
for dh, dl in zip(deltas_human, deltas_llama):
    if (dh > 0 and dl > 0) or (dh < 0 and dl < 0):
        agreement.append(1)
    else:
        agreement.append(-1)

# Set positions of bars on x-axis
r = np.arange(len(agreement))

# Create the plot
plt.figure(figsize=(14, 7))

# Plot agreement values
plt.bar(r, agreement, color=['green' if x == 1 else 'red' for x in agreement], width=0.6, edgecolor='grey')

# Labeling the plot
plt.title('Agreement in Changes of Average Suspense Rating (Human vs Llama)')
plt.xlabel('Text Segment')
plt.ylabel('Agreement Value (+1 for Agreement, -1 for Disagreement)')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)  # Add a horizontal line at y=0
plt.xticks(r, text_segments_deltas, rotation=90)  # Rotate x-axis labels if necessary

# Add a legend
handles = [
    plt.Rectangle((0,0),1,1, color='green'),
    plt.Rectangle((0,0),1,1, color='red')
]
labels = [
    'Agreement (Both Positive or Both Negative)',
    'Disagreement (One Positive, One Negative)'
]
plt.legend(handles, labels)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
suspense_ratings_human = [5.565217391, 5, 4.826086957, 5.739130435, 5.52173913, 6.826086957, 7.304347826,
                          5.434782609, 6.391304348, 7.47826087, 7.043478261, 5.869565217, 6.739130435,
                          6.956521739, 6.47826087, 5.956521739, 4.652173913, 4.260869565, 5.173913043,
                          4.086956522, 4.173913043, 4.304347826, 5, 4.043478261, 4.217391304, 4.434782609,
                          5.347826087, 6.217391304, 5.434782609, 4.782608696, 6.173913043, 5.956521739,
                          6.47826087, 5, 4.739130435, 5.173913043, 6.304347826, 6.434782609, 5.260869565,
                          5.304347826, 5.956521739, 4.304347826, 5.260869565, 4.391304348, 4.956521739,
                          5.695652174, 5.043478261, 5.826086957, 5.043478261, 4.913043478, 5.217391304,
                          6.217391304, 6.391304348, 6.52173913, 7.217391304, 6.565217391, 5.52173913,
                          4.347826087, 3.869565217, 7, 7.565217391, 6.52173913, 6.260869565, 6.043478261,
                          4.913043478]

suspense_ratings_llama = [5, 2, 1, 9, 3, 8, 9, 10, 9, 10, 9, 8, 6, 8, 10, 5, 2, 4, 6, 5, 8, 4, 9, 5, 1, 3, 6, 8, 9, 10, 10, 10, 10, 10, 8, 5, 8, 10, 9, 10, 10, 10, 9, 8, 6, 10, 10, 10, 10, 8, 6, 10, 10, 10, 10, 10, 10, 1, 1, 10, 10, 10, 10, 10, 1]

# Calculate differences (deltas)
deltas_human = [suspense_ratings_human[i] - suspense_ratings_human[i - 1] for i in range(1, len(suspense_ratings_human))]
deltas_llama = [suspense_ratings_llama[i] - suspense_ratings_llama[i - 1] for i in range(1, len(suspense_ratings_llama))]

# Generate x-axis labels for deltas as text segments
text_segments_deltas = list(range(2, len(suspense_ratings_human) + 1))

# Calculate agreement and disagreement values
values = []
colors = []
for dh, dl in zip(deltas_human, deltas_llama):
    if (dh > 0 and dl > 0) or (dh < 0 and dl < 0):
        # Agreement
        values.append(abs(dh - dl))
        colors.append('green')
    else:
        # Disagreement
        values.append(-(abs(dh - dl)))
        colors.append('red')

# Set positions of bars on x-axis
r = np.arange(len(values))

# Create the plot
plt.figure(figsize=(14, 7))

# Plot values
plt.bar(r, values, color=colors, width=0.6, edgecolor='grey')

# Labeling the plot
plt.title('Change in Average Suspense Rating (Human vs Llama) with Agreement and Disagreement')
plt.xlabel('Text Segment')
plt.ylabel('Difference in Rating Change')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)  # Add a horizontal line at y=0
plt.xticks(r, text_segments_deltas, rotation=90)  # Rotate x-axis labels if necessary

# Add a legend
handles = [
    plt.Rectangle((0,0),1,1, color='green'),
    plt.Rectangle((0,0),1,1, color='red')
]
labels = [
    'Agreement (Difference in Change)',
    'Disagreement (Negative Difference)'
]
plt.legend(handles, labels)

# Show the plot
plt.show()
